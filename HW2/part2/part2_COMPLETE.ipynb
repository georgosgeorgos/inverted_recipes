# %%
import requests
import re
import time
import pandas as pd
from bs4 import BeautifulSoup
import string
import json
import nltk
import csv

# %%
with open('dictHTML.json', 'r') as fp:     
    
    dHTML = json.load(fp)         # ATTENTION DON'T PRINT ALL THIS

# %%
with open('dictRecipes.json', 'r') as fp:
    
    dictRecipes = json.load(fp)

# %%
def extractTitle(soup):
    
    title = "NA"
    
    try:
         title = soup.title.contents[0]
    except:
        
        title = "NA"
        
    return title

extractTitle(soup)
# Out:
# 'BBC Food - Recipes - Tamarind seared tuna steak with melon salad and zingy dressing'

# %%
def extractAuthor(soup):

    author = "NA"

    for link in soup.find_all("a"):
        
        try:
             if link.get("class") == ["chef__link"] and link.get("itemprop") == "author":

                    author = link.contents[0]
        except:
            
            author = "NA"
            
   
    return author        
            
extractAuthor(soup)
# Out:
# 'James Martin'

# %%
def extractPrepTime(soup):

    prep = "NA"

    for link in soup.find_all("p"):
        
        try:
        
            if link.get("class") == ["recipe-metadata__prep-time"]:

                    prep = link.contents[0]
        except:
            
            prep = "NA"
            
            
        
    return prep

# %%
def extractCookTime(soup):

    cook = "NA"

    for link in soup.find_all("p"):
        
        try:
        
            if link.get("class") == ["recipe-metadata__cook-time"]:

                    cook = link.contents[0]
        except:
            
            cook = "NA"
               
    return cook

# %%
def extractServes(soup):

    serves = "NA"

    for link in soup.find_all("p"):
        
        try:
            if link.get("class") == ["recipe-metadata__serving"] and link.get("itemprop") == "recipeYield":

                    serves = link.contents[0]
        except:
            
            serves = "NA"
            
            
        
    return serves

# %%
def extractDietary(soup):

    diet = "NA"

    for link in soup.find_all("p"):
        
        try:
            if link.get("class") == ["recipe-metadata__dietary-vegetarian-text"]:

                    diet = link.contents[0]
        except:
            
            diet = "NA"
               
    return diet

# %%
def extractIngredients(soup):

    ingredients = []

    for link in soup.find_all(itemprop = "ingredients"):
        try:
            if link.a != None:

                ingredients.extend(link.a.contents)
        except:
                ingredients = "NA"
            
    return ingredients

# %%
def extractMethods(soup):

    methods = []

    for link in soup.find_all(itemprop = "recipeInstructions"):
        try:
            methods.extend(link.p.contents)
        except:
            methods = "NA"
            
    return methods

# %%
def extract(soup):
    
    
    title = extractTitle(soup)
    author = extractAuthor(soup)
    serves = extractServes(soup)
    prepTime = extractPrepTime(soup)
    cookTime = extractCookTime(soup)
    dietary = extractDietary(soup)
    ingredients = extractIngredients(soup)
    methods = extractMethods(soup)
    
    return title,author,serves,prepTime, cookTime, dietary, ingredients, methods

# %%
#tsv = open('data.csv', 'w')
    
#fieldnames = ["title","author","serves","prepTime", "cookTime", "dietary", "ingredients", "methods"]
#writer = csv.DictWriter(tsv, fieldnames=fieldnames, delimiter = "\t")
#writer.writeheader()

#for key in range(0,len(dictRecipes)):
#    print(key)
    
#    if key%1000 == 0:
#        time.sleep(10)
#    soup = BeautifulSoup(dHTML[str(key)], "lxml")
#    title,author,serves,prepTime, cookTime, dietary, ingredients, methods = extract(soup)

#    writer.writerow({"title": title, "author": author, "serves": serves, "prepTime":prepTime, 
#                     "cookTime":cookTime, "dietary": dietary, "ingredients": ingredients, "methods": methods})
    
#tsv.close()

# %%
with open('data.csv') as tsv:
    fieldnames = ["title","author","serves","prepTime", "cookTime", "dietary", "ingredients", "methods"]
    reader = csv.DictReader(tsv, fieldnames=fieldnames, delimiter = "\t")
    for row in reader:
        print(row['serves'])

# %%
with open('data.csv') as tsv:
    
    frame = pd.read_csv(tsv, header=0, sep='\t')

# %%
frame
# Out:
#                                                    title  \
# 0      BBC Food - Recipes - Tamarind seared tuna stea...
# 1      BBC Food - Recipes - Wild rabbit and morel ste...
# 2      BBC Food - Recipes - Prawn fritters with saffr...
# 3      BBC Food - Recipes - Turkey stuffing meatballs...
# 4                 BBC Food - Recipes - Mango tarte tatin
# 5      BBC Food - Recipes - Sautéed apples with whisk...
# 6      BBC Food - Recipes - Steak, tomatoes and mozza...
# 7      BBC Food - Recipes - Thyme and garlic-roasted ...
# 8      BBC Food - Recipes - Chargrilled T-bone steak ...
# 9      BBC Food - Recipes - Herb-crusted rack of lamb...
# 10      BBC Food - Recipes - Leek, onion and garlic soup
# 11     BBC Food - Recipes - Vanilla and golden syrup ...
# 12                   BBC Food - Recipes - Chicken tagine
# 13     BBC Food - Recipes - Braised chicken wings and...
# 14                BBC Food - Recipes - Vegetable samosas
# 15     BBC Food - Recipes - Herring with dill and mus...
# 16        BBC Food - Recipes - Lemon and lime cheesecake
# 17     BBC Food - Recipes - Tandoori spiced pork chop...
# 18     BBC Food - Recipes - Chargrilled squid with sa...
# 19     BBC Food - Recipes - Cheese and potato cakes w...
# 20     BBC Food - Recipes - Cranachan with fresh Skye...
# 21     BBC Food - Recipes - Chilli cheese croquettes ...
# 22     BBC Food - Recipes - Sweet potato and broad be...
# 23      BBC Food - Recipes - Pumpkin pasta with rosemary
# 24            BBC Food - Recipes - Cambozola dauphinoise
# 25     BBC Food - Recipes - Spiced spring lamb with b...
# 26     BBC Food - Recipes - Basil sorbet with individ...
# 27               BBC Food - Recipes - Chocolate palmiers
# 28     BBC Food - Recipes - Wonton baskets filled wit...
# 29                      BBC Food - Recipes - Banana cake
# ...                                                  ...
# 11195  BBC Food - Recipes - Fried christophine with c...
# 11196  BBC Food - Recipes - Bulgar wheat salad with s...
# 11197          BBC Food - Recipes - Melon with parma ham
# 11198                  BBC Food - Recipes - Lemon posset
# 11199  BBC Food - Recipes - Griddled pineapple with a...
# 11200   BBC Food - Recipes - Winter Swiss roll bowl cake
# 11201           BBC Food - Recipes - Wensleydale rarebit
# 11202       BBC Food - Recipes - Apple and bacon chutney
# 11203  BBC Food - Recipes - Baked mango with whipped ...
# 11204      BBC Food - Recipes - Blueberry muffin Martini
# 11205           BBC Food - Recipes - Hot chocolate sauce
# 11206              BBC Food - Recipes - Vegetarian plait
# 11207                     BBC Food - Recipes - Clam soup
# 11208       BBC Food - Recipes - Thai-style fish parcels
# 11209              BBC Food - Recipes - Honey cheesecake
# 11210  BBC Food - Recipes - Baba ganoush, grilled aub...
# 11211                    BBC Food - Recipes - Party eggs
# 11212  BBC Food - Recipes - Passion fruit cheesecakes...
# 11213  BBC Food - Recipes - Porcini mushroom cream sauce
# 11214  BBC Food - Recipes - Watercress soup with a po...
# 11215  BBC Food - Recipes - Jasmine rice with lime an...
# 11216               BBC Food - Recipes - Tomato concasse
# 11217  BBC Food - Recipes - Pear, cheese and tomato s...
# 11218  BBC Food - Recipes - Fried baby pineapple with...
# 11219             BBC Food - Recipes - Tea-time mackerel
# 11220               BBC Food - Recipes - Aubergine curry
# 11221  BBC Food - Recipes - Cold seared salmon with c...
# 11222  BBC Food - Recipes - Prunes with orange and va...
# 11223     BBC Food - Recipes - Vegetable and salmon bake
# 11224          BBC Food - Recipes - Italian-style trifle
#
#                                author           serves           prepTime  \
# 0                        James Martin         Serves 4          overnight
# 1                        James Martin         Serves 4  less than 30 mins
# 2                        José Pizarro         Serves 2          overnight
# 3                       Lesley Waters         Serves 1  less than 30 mins
# 4                         Paul Rankin         Serves 1  less than 30 mins
# 5                        Phil Vickery         Serves 1  less than 30 mins
# 6                       Gino D'Acampo         Serves 1  less than 30 mins
# 7                       Garrey Dawson         Serves 1  less than 30 mins
# 8                        James Martin         Serves 4  less than 30 mins
# 9                        James Martin         Serves 4       over 2 hours
# 10                       James Tanner         Serves 1  less than 30 mins
# 11                       James Tanner       Serves 1-2  less than 30 mins
# 12                      Mourad Mazouz         Serves 4  less than 30 mins
# 13                      Bryn Williams         Serves 4  less than 30 mins
# 14                   The Hairy Bikers         Makes 12  less than 30 mins
# 15                       Simon Rimmer                4  less than 30 mins
# 16        Kate Morris and Sally Brown          Makes 2  30 mins to 1 hour
# 17                       Atul Kochhar         Serves 4  30 mins to 1 hour
# 18                         Nick Nairn         Serves 1  less than 30 mins
# 19                      Lesley Waters       Serves 1-2  less than 30 mins
# 20                      Shirley Spear         Serves 4  less than 30 mins
# 21                       James Martin         Serves 4  30 mins to 1 hour
# 22                        Paul Rankin         Serves 1  less than 30 mins
# 23                       James Martin         Serves 4  less than 30 mins
# 24                         Nick Nairn         Serves 1  less than 30 mins
# 25                         Mary Berry         Serves 6  less than 30 mins
# 26                       James Martin         Serves 4  less than 30 mins
# 27                         Nick Nairn         Serves 1  less than 30 mins
# 28                       Atul Kochhar        Serves 12  less than 30 mins
# 29                        Jaye Jacobs   Makes 2 loaves  less than 30 mins
# ...                               ...              ...                ...
# 11195                      Levi Roots         Serves 1  less than 30 mins
# 11196                    Phil Vickery         Serves 1  less than 30 mins
# 11197                    Phil Vickery         Serves 2  less than 30 mins
# 11198                    James Martin         Serves 1  less than 30 mins
# 11199                   Lesley Waters         Serves 1  less than 30 mins
# 11200                Lorraine Pascale     Serves 10-12       over 2 hours
# 11201                    Phil Vickery         Serves 2  less than 30 mins
# 11202                       Ed Baines         Serves 2  less than 30 mins
# 11203                   Gino D'Acampo         Serves 1  less than 30 mins
# 11204             Salvatore Calabrese         Serves 1  less than 30 mins
# 11205                     Paul Rankin         Serves 1  less than 30 mins
# 11206                   Elizabeth Guy         Serves 4  less than 30 mins
# 11207                    James Tanner         Serves 1  less than 30 mins
# 11208                    Simon Rimmer         Serves 4       over 2 hours
# 11209                    Brian Turner         Serves 1  less than 30 mins
# 11210                    Matt Tebbutt         Serves 4  less than 30 mins
# 11211  Neil Strawson and Richard Hunt          Makes 4  less than 30 mins
# 11212                   Lesley Waters         Serves 2  less than 30 mins
# 11213                    Brian Turner         Serves 2  less than 30 mins
# 11214                     Alex Mackay         Serves 1  less than 30 mins
# 11215                Richard Phillips         Serves 2  less than 30 mins
# 11216                    Andrew Blake  Makes 1 portion  less than 30 mins
# 11217                     Alex Mackay         Serves 1  less than 30 mins
# 11218                      Levi Roots         Serves 1  less than 30 mins
# 11219                    Nigel Slater   Makes 4 toasts  less than 30 mins
# 11220                     Ross Burden       Serves 1-2  less than 30 mins
# 11221                       Rob Kirby         Serves 4  less than 30 mins
# 11222                    Phil Vickery         Serves 1  less than 30 mins
# 11223                      Tony Tobin       Serves 1-2  less than 30 mins
# 11224                      Tony Tobin         Serves 1  less than 30 mins
#
#                   cookTime                                            dietary  \
# 0            10 to 30 mins                                                NaN
# 1             1 to 2 hours                                                NaN
# 2            10 to 30 mins                                                NaN
# 3            10 to 30 mins                                                NaN
# 4            10 to 30 mins  \n                    Vegetarian\n            ...
# 5        less than 10 mins  \n                    Vegetarian\n            ...
# 6        less than 10 mins                                                NaN
# 7            10 to 30 mins  \n                    Vegetarian\n            ...
# 8        30 mins to 1 hour                                                NaN
# 9        30 mins to 1 hour                                                NaN
# 10           10 to 30 mins  \n                    Vegetarian\n            ...
# 11           10 to 30 mins  \n                    Vegetarian\n            ...
# 12       30 mins to 1 hour                                                NaN
# 13       30 mins to 1 hour                                                NaN
# 14            1 to 2 hours  \n                    Vegetarian\n            ...
# 15           10 to 30 mins                                                NaN
# 16     no cooking required  \n                    Vegetarian\n            ...
# 17       30 mins to 1 hour                                                NaN
# 18       less than 10 mins                                                NaN
# 19       less than 10 mins                                                NaN
# 20     no cooking required  \n                    Vegetarian\n            ...
# 21       30 mins to 1 hour  \n                    Vegetarian\n            ...
# 22           10 to 30 mins  \n                    Vegetarian\n            ...
# 23       30 mins to 1 hour  \n                    Vegetarian\n            ...
# 24           10 to 30 mins  \n                    Vegetarian\n            ...
# 25            over 2 hours                                                NaN
# 26           10 to 30 mins  \n                    Vegetarian\n            ...
# 27       less than 10 mins  \n                    Vegetarian\n            ...
# 28       less than 10 mins  \n                    Vegetarian\n            ...
# 29            1 to 2 hours  \n                    Vegetarian\n            ...
# ...                    ...                                                ...
# 11195        10 to 30 mins  \n                    Vegetarian\n            ...
# 11196        10 to 30 mins                                                NaN
# 11197  no cooking required                                                NaN
# 11198  no cooking required  \n                    Vegetarian\n            ...
# 11199    less than 10 mins  \n                    Vegetarian\n            ...
# 11200  no cooking required  \n                    Vegetarian\n            ...
# 11201    less than 10 mins  \n                    Vegetarian\n            ...
# 11202        10 to 30 mins                                                NaN
# 11203    less than 10 mins  \n                    Vegetarian\n            ...
# 11204  no cooking required  \n                    Vegetarian\n            ...
# 11205        10 to 30 mins  \n                    Vegetarian\n            ...
# 11206         1 to 2 hours  \n                    Vegetarian\n            ...
# 11207    less than 10 mins                                                NaN
# 11208        10 to 30 mins                                                NaN
# 11209  no cooking required  \n                    Vegetarian\n            ...
# 11210        10 to 30 mins  \n                    Vegetarian\n            ...
# 11211  no cooking required                                                NaN
# 11212  no cooking required  \n                    Vegetarian\n            ...
# 11213    less than 10 mins  \n                    Vegetarian\n            ...
# 11214    less than 10 mins  \n                    Vegetarian\n            ...
# 11215        10 to 30 mins  \n                    Vegetarian\n            ...
# 11216    less than 10 mins  \n                    Vegetarian\n            ...
# 11217  no cooking required  \n                    Vegetarian\n            ...
# 11218    less than 10 mins  \n                    Vegetarian\n            ...
# 11219    less than 10 mins                                                NaN
# 11220        10 to 30 mins  \n                    Vegetarian\n            ...
# 11221        10 to 30 mins                                                NaN
# 11222  no cooking required  \n                    Vegetarian\n            ...
# 11223        10 to 30 mins                                                NaN
# 11224  no cooking required  \n                    Vegetarian\n            ...
#
#                                              ingredients  \
# 0      ['watermelon', 'melon', 'beans', 'sugar-snap p...
# 1      ['plain flour', 'black pepper', 'rabbit', 'veg...
# 2      ['prawns', 'limes', 'red onion', 'chilli', 'sh...
# 3      ['turkey', 'stuffing', 'egg', 'plain flour', '...
# 4      ['plain flour', 'caster sugar', 'butter', 'egg...
# 5      ['caster sugar', 'apples', 'vanilla pod', 'ora...
# 6      ['sirloin', 'breadcrumbs', 'parsley', 'black p...
# 7      ['olive oil', 'swede', 'potato', 'garlic', 'ro...
# 8      ['vinegar', 'brown sugar', 'tomatoes', 'onions...
# 9      ['ciabatta', 'lemon', 'capers', 'onions', 'oli...
# 10     ['olive oil', 'leek', 'garlic', 'onion', 'vege...
# 11     ['milk', 'double cream', 'golden syrup', 'vani...
# 12     ['olives', 'olive oil', 'onion', 'chicken brea...
# 13     ['chicken wings', 'black pepper', 'butter', 'o...
# 14     ['flour', 'salt', 'oil', 'egg', 'potatoes', 'c...
# 15     ['limes', 'white wine', 'peppercorns', 'bay le...
# 16     ['biscuits', 'butter', 'lemon', 'lime', 'icing...
# 17     ['garlic', 'fennel seeds', 'cinnamon', 'rosema...
# 18     ['squid', 'olive oil', 'black pepper', 'olives...
# 19     ['mashed potato', 'gruyère', 'self-raising flo...
# 20        ['double cream', 'honey', 'whisky', 'oatmeal']
# 21     ['King Edward', 'garlic', 'olive oil', 'chedda...
# 22     ['olive oil', 'shallots', 'garlic', 'broad bea...
# 23     ['pasta', 'pumpkin', 'rosemary', 'garlic', 'sh...
# 24     ['double cream', 'new potatoes', 'garlic', 'bl...
# 25     ['lamb neck', 'sunflower oil', 'garlic', 'onio...
# 26     ['caster sugar', 'basil', 'lemon juice', 'milk...
# 27     ['puff pastry', 'icing sugar', 'cocoa powder',...
# 28     ['icing sugar', 'lemon', 'double cream', 'lemo...
# 29     ['bananas', 'vegetable oil', 'butter', 'caster...
# ...                                                  ...
# 11195                     ['butter', 'chilli', 'chilli']
# 11196  ['raisins', 'oranges', 'lime juice', 'seeds', ...
# 11197                                 ['melon', 'basil']
# 11198  ['double cream', 'lemon curd', 'biscuits', 'fl...
# 11199  ['pineapple', 'honey', 'orange juice', 'double...
# 11200                               ['rum', 'ice cream']
# 11201  ['Wensleydale', 'wholegrain mustard', 'egg yol...
# 11202  ['apple', 'plum', 'balsamic vinegar', 'white w...
# 11203  ['mango', 'honey', 'chilli', 'cinnamon', 'doub...
# 11204                    ['vodka', 'blueberry', 'vodka']
# 11205  ['dark chocolate', 'double cream', 'brandy', '...
# 11206  ['peppers', 'peppers', 'peppers', 'red onions'...
# 11207  ['butter', 'onion', 'fennel', 'vegetable stock...
# 11208  ['ginger', 'lime leaves', 'lemongrass', 'cocon...
# 11209                 ['yoghurt', 'mascarpone', 'honey']
# 11210  ['aubergines', 'garlic', 'lemon', 'tahini', 'o...
# 11211  ['eggs', 'salad cream', 'cherry tomatoes', 'ba...
# 11212  ['mascarpone', 'shortbread', 'double cream', '...
# 11213  ['butter', 'garlic', 'shallot', 'mushrooms', '...
# 11214  ['vegetable stock', 'watercress', 'egg', 'whit...
# 11215  ['rice', 'cloves', 'cardamom', 'lime', 'corian...
# 11216                                                 []
# 11217  ['pear', 'orange', 'cream cheese', 'lemon', 't...
# 11218  ['butter', 'pineapple', 'double cream', 'mint'...
# 11219  ['bread', 'smoked mackerel', 'double cream', '...
# 11220  ['lemongrass', 'garlic', 'chilli', 'fresh cori...
# 11221  ['salmon', 'lemon', 'pesto', 'peas', 'broad be...
# 11222  ['yoghurt', 'vanilla pod', 'prunes', 'orange',...
# 11223  ['double cream', 'potato', 'leek', 'cheddar', ...
# 11224  ['whisky', 'double cream', 'mascarpone', 'dark...
#
#                                                  methods
# 0      ['For the salad, place the sliced melons in a ...
# 1      ['For the wild rabbit and morel stew, sprinkle...
# 2      ['For the prawn fritters, mix the prawns with ...
# 3      ['Preheat the oven to 180C/350F/Gas 4.', 'For ...
# 4      ['Preheat the oven to 200C/400F/Gas 6.', 'For ...
# 5      ['Heat the sugar, apple slices and vanilla see...
# 6      ['Slice the sirloin steak in half lengthways a...
# 7      ['Preheat the oven to 200C/400F/Gas 6.', 'Heat...
# 8      ['For the chutney, place the vinegar and sugar...
# 9      ['Firstly, make the herb crust. Preheat the ov...
# 10     ['Heat the oil in a small saucepan, add the le...
# 11     ['For the rice pudding, heat the milk, cream, ...
# 12     ['Heat the olive oil in a heavy saucepan. Add ...
# 13     ['For the braised chicken wings, season the ch...
# 14     ['For the pastry, mix the flour and salt toget...
# 15     ['For the herring, bring the water, lime juice...
# 16     ['Put the biscuits in sandwich bag and use a r...
# 17     ['Preheat the oven to 180C/350F/Gas 4.', 'For ...
# 18     ['For the chargrilled squid, rub the squid wit...
# 19     ['For the potato cakes, place the mashed potat...
# 20     ['Whisk the cream together with the honey and ...
# 21     ['For the chilli cheese croquettes, place the ...
# 22     ['Heat the oil in a saucepan over a medium hea...
# 23     ['Preheat the oven 190C/375F/Gas 5. ', 'Peel a...
# 24     ['Preheat the oven to 180C/350F/Gas 4.', 'Brin...
# 25     ['Remove any excess fat from the lamb and cut ...
# 26     ['For the sorbet, place the sugar, water and b...
# 27     ['Preheat the oven to 220C/425F/Gas 7.', 'Roll...
# 28     ['Preheat the oven to 200C/400F/Gas 6.', "For ...
# 29     ['Preheat the oven to 200C/400F/Gas 6. Grease ...
# ...                                                  ...
# 11195  ['Parboil the christophine slices in boiling w...
# 11196  ['For the salad, place the bulgar wheat in a l...
# 11197  ['Place two basil leaves on top of each piece ...
# 11198  ['In a small bowl mix together the whipped cre...
# 11199  ['For the griddled pineapple, heat a griddle p...
# 11200  ['Line the inside of a medium glass bowl or 1....
# 11201  ['Preheat the grill to medium.', 'Place the ch...
# 11202  ['Place all the ingredients, except the bacon,...
# 11203  ['Preheat the oven to 180C/350F/Gas 4.', 'Plac...
# 11204  ['Place all of the ingredients into a cocktail...
# 11205  ['Place the chocolate, double cream, brandy an...
# 11206  ['Preheat the oven to 200C/400F/Gas 6.', 'Roug...
# 11207  ['Melt the butter in a saucepan.', 'Sweat the ...
# 11208  ['Place the chopped ginger, lime leaves, chill...
# 11209  ["Line the base of a metal medium-size chefs' ...
# 11210  ['For the baba ganoush, hold the aubergines ov...
# 11211  ['Carefully remove the yolk from the eggs and ...
# 11212  ['Place the mascarpone, crushed shortbread, cr...
# 11213  ['Melt the butter in a small saucepan over a m...
# 11214  ['Bring the stock to a simmer in a pan, then s...
# 11215  ['Place the rice into a pan with a lid. Cover ...
# 11216  ['With a paring knife, score the tomatoes with...
# 11217  ['Arrange the pear slices on a serving plate a...
# 11218  ['Melt the butter in a frying pan and lightly ...
# 11219  ['Have four slices of your favourite bread rea...
# 11220  ['Blend the lemongrass, garlic, chilli, corian...
# 11221  ['Sear the salmon in a hot frying pan and fini...
# 11222  ['Place the yoghurt with the vanilla seeds int...
# 11223  ['Preheat the oven to 220C/425F/Gas 7', 'Place...
# 11224  ['For the chocolate cream, place all of the in...
#
# [11225 rows x 8 columns]
